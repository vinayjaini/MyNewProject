# %%
import pandas as pd 
import numpy as nd

# %%
uber_data = pd.read_csv("C:/Users/vinay/Downloads/Uber Request Data (1).csv")

# %%
uber_data.head(10)
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed  11/07/2016 11:51:00
# 1         867      Airport        1.0  Trip Completed  11/07/2016 17:57:00
# 2        1807         City        1.0  Trip Completed  12/07/2016 09:17:00
# 3        2532      Airport        1.0  Trip Completed  12/07/2016 21:08:00
# 4        3112         City        1.0  Trip Completed  13/07/2016 08:33:16
# 5        3879      Airport        1.0  Trip Completed  13/07/2016 21:57:28
# 6        4270      Airport        1.0  Trip Completed  14/07/2016 06:15:32
# 7        5510      Airport        1.0  Trip Completed  15/07/2016 05:11:52
# 8        6248         City        1.0  Trip Completed  15/07/2016 17:57:27
# 9         267         City        2.0  Trip Completed  11/07/2016 06:46:00
#
#         Drop timestamp
# 0  11/07/2016 13:00:00
# 1  11/07/2016 18:47:00
# 2  12/07/2016 09:58:00
# 3  12/07/2016 22:03:00
# ...

# %%
#checking for duplicate Request id

# %%
print(any(uber_data["Request id"].duplicated()))
# Out:
# False

# %%
#data cleaning
##The date and time are in an inconsistent format

# %%
pd.to_datetime(uber_data['Request timestamp'], infer_datetime_format=True)
# Out:
# 0      2016-11-07 11:51:00
# 1      2016-11-07 17:57:00
# 2      2016-12-07 09:17:00
# 3      2016-12-07 21:08:00
# 4      2016-07-13 08:33:16
# 5      2016-07-13 21:57:28
# 6      2016-07-14 06:15:32
# 7      2016-07-15 05:11:52
# 8      2016-07-15 17:57:27
# 9      2016-11-07 06:46:00
# 10     2016-12-07 05:08:00
# 11     2016-12-07 12:30:00
# 12     2016-07-13 04:49:20
# 13     2016-07-13 08:02:53
# 14     2016-07-13 14:23:02
# 15     2016-07-13 17:23:18
# 16     2016-07-14 12:01:02
# 17     2016-07-14 22:24:13
# 18     2016-11-07 10:00:00
# 19     2016-11-07 18:45:00
# 20     2016-12-07 11:17:00
# 21     2016-12-07 15:46:00
# 22     2016-12-07 18:00:00
# 23     2016-07-13 08:17:29
# 24     2016-07-13 21:54:18
# 25     2016-07-14 21:23:03
# 26     2016-07-15 02:41:38
# 27     2016-07-15 10:00:43
# 28     2016-11-07 13:08:00
# 29     2016-12-07 06:21:00
#                ...
# 6715   2016-07-15 22:34:01
# 6716   2016-07-15 22:36:13
# 6717   2016-07-15 22:37:37
# ...

# %%
pd.to_datetime(uber_data['Drop timestamp'], infer_datetime_format=True)
# Out:
# 0      2016-11-07 13:00:00
# 1      2016-11-07 18:47:00
# 2      2016-12-07 09:58:00
# 3      2016-12-07 22:03:00
# 4      2016-07-13 09:25:47
# 5      2016-07-13 22:28:59
# 6      2016-07-14 07:13:15
# 7      2016-07-15 06:07:52
# 8      2016-07-15 18:50:51
# 9      2016-11-07 07:25:00
# 10     2016-12-07 06:02:00
# 11     2016-12-07 12:57:00
# 12     2016-07-13 05:23:03
# 13     2016-07-13 09:16:19
# 14     2016-07-13 15:35:18
# 15     2016-07-13 18:20:51
# 16     2016-07-14 12:36:46
# 17     2016-07-14 23:18:52
# 18     2016-11-07 10:31:00
# 19     2016-11-07 19:23:00
# 20     2016-12-07 12:23:00
# 21     2016-12-07 16:40:00
# 22     2016-12-07 18:28:00
# 23     2016-07-13 09:22:37
# 24     2016-07-13 22:51:23
# 25     2016-07-14 22:25:19
# 26     2016-07-15 03:24:43
# 27     2016-07-15 10:53:06
# 28     2016-11-07 13:49:00
# 29     2016-12-07 07:10:00
#                ...
# 6715                   NaT
# 6716                   NaT
# 6717                   NaT
# ...

# %%
uber_data.head(10)
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed  11/07/2016 11:51:00
# 1         867      Airport        1.0  Trip Completed  11/07/2016 17:57:00
# 2        1807         City        1.0  Trip Completed  12/07/2016 09:17:00
# 3        2532      Airport        1.0  Trip Completed  12/07/2016 21:08:00
# 4        3112         City        1.0  Trip Completed  13/07/2016 08:33:16
# 5        3879      Airport        1.0  Trip Completed  13/07/2016 21:57:28
# 6        4270      Airport        1.0  Trip Completed  14/07/2016 06:15:32
# 7        5510      Airport        1.0  Trip Completed  15/07/2016 05:11:52
# 8        6248         City        1.0  Trip Completed  15/07/2016 17:57:27
# 9         267         City        2.0  Trip Completed  11/07/2016 06:46:00
#
#         Drop timestamp
# 0  11/07/2016 13:00:00
# 1  11/07/2016 18:47:00
# 2  12/07/2016 09:58:00
# 3  12/07/2016 22:03:00
# ...

# %%
uber_data['Request timestamp'] = pd.to_datetime(uber_data['Request timestamp'], format="%d/%m/%Y %H:%M:%S")

# %%
uber_data['hr'] =  uber_data['Request timestamp'].dt.hour

# %%
uber_data['MinOfDay'] = uber_data['Request timestamp'].dt.minute

# %%
uber_data['Reqeust Date'] = uber_data['Request timestamp'].dt.date

# %%
uber_data['Request Time'] = uber_data['Request timestamp'].dt.time

# %%
uber_data['Drop timestamp'] = pd.to_datetime(uber_data['Drop timestamp'], format="%d/%m/%Y %H:%M:%S")

# %%
uber_data['Drop Date'] = uber_data['Drop timestamp'].dt.date

# %%
uber_data['Drop Time'] = uber_data['Drop timestamp'].dt.time

# %%
uber_data.head(10)
# Out:
#       Request id Pickup point  Driver id             Status  \
# 2700           1      Airport      285.0     Trip Completed
# 4098           2      Airport        NaN  No Cars Available
# 776            3      Airport       80.0     Trip Completed
# 4101           4         City        NaN  No Cars Available
# 2506           5      Airport      264.0     Trip Completed
# 4100           6         City        NaN  No Cars Available
# 4099           7      Airport        NaN  No Cars Available
# 4102           8         City        NaN  No Cars Available
# 2245           9      Airport      235.0     Trip Completed
# 2173          10         City      228.0     Trip Completed
#
#        Request timestamp      Drop timestamp  hr  MinOfDay Reqeust Date  \
# 2700 2016-07-11 00:20:00 2016-07-11 00:51:00   0        20   2016-07-11
# 4098 2016-07-11 00:23:00                 NaT   0        23   2016-07-11
# 776  2016-07-11 00:24:00 2016-07-11 01:31:00   0        24   2016-07-11
# ...

# %%
uber_data = uber_data.sort_values(['hr'] )

# %%
uber_data['Segment']='NA'

# %%
uber_data['Segment'].loc[uber_data['hr'] == 0] = 'Late night'
uber_data['Segment'].loc[uber_data['hr'] == 1] = 'Late night'
uber_data['Segment'].loc[uber_data['hr'] == 2] = 'Late night'
uber_data['Segment'].loc[uber_data['hr'] == 3] = 'Late night'
uber_data['Segment'].loc[uber_data['hr'] == 4] = 'Early morning'
uber_data['Segment'].loc[uber_data['hr'] == 5] = 'Early morning'
uber_data['Segment'].loc[uber_data['hr'] == 6] = 'Early morning'
uber_data['Segment'].loc[uber_data['hr'] == 7] = 'Morning'
uber_data['Segment'].loc[uber_data['hr'] == 8] = 'Morning'
uber_data['Segment'].loc[uber_data['hr'] == 9] = 'Morning'
uber_data['Segment'].loc[uber_data['hr'] == 10] = 'Morning'
uber_data['Segment'].loc[uber_data['hr'] == 11] = 'Morning'
uber_data['Segment'].loc[uber_data['hr'] == 12] = 'After noon'
uber_data['Segment'].loc[uber_data['hr'] == 13] = 'After noon'
uber_data['Segment'].loc[uber_data['hr'] == 14] = 'After noon'
uber_data['Segment'].loc[uber_data['hr'] == 15] = 'After noon'
uber_data['Segment'].loc[uber_data['hr'] == 16] = 'Evening'
uber_data['Segment'].loc[uber_data['hr'] == 17] = 'Evening'
uber_data['Segment'].loc[uber_data['hr'] == 18] = 'Evening'
uber_data['Segment'].loc[uber_data['hr'] == 19] = 'Evening'
uber_data['Segment'].loc[uber_data['hr'] == 20] = 'Night'
uber_data['Segment'].loc[uber_data['hr'] == 21] = 'Night'
uber_data['Segment'].loc[uber_data['hr'] == 22] = 'Night'
uber_data['Segment'].loc[uber_data['hr'] == 23] = 'Night'
# Out:
# C:\Users\vinay\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
uber_data.tail(1000)
# Out:
#       Request id Pickup point  Driver id             Status  \
# 5443        3724      Airport        NaN  No Cars Available
# 5444        3721      Airport        NaN  No Cars Available
# 5445        3729      Airport        NaN  No Cars Available
# 5446        3731      Airport        NaN  No Cars Available
# 5447        3733      Airport        NaN  No Cars Available
# 5448        3730      Airport        NaN  No Cars Available
# 5449        3735      Airport        NaN  No Cars Available
# 5450        3734      Airport        NaN  No Cars Available
# 5451        3737      Airport        NaN  No Cars Available
# 5453        3746      Airport        NaN  No Cars Available
# 3762        2448      Airport      222.0          Cancelled
# 5467        3760      Airport        NaN  No Cars Available
# 743         1112      Airport       77.0     Trip Completed
# 833         3809         City       85.0     Trip Completed
# 3823        1117      Airport      235.0          Cancelled
# ...

# %%
uber_data = uber_data.sort_values(['Request id'] )

# %%
uber_data.head(100)
# Out:
#       Request id Pickup point  Driver id             Status  \
# 2700           1      Airport      285.0     Trip Completed
# 4098           2      Airport        NaN  No Cars Available
# 776            3      Airport       80.0     Trip Completed
# 4101           4         City        NaN  No Cars Available
# 2506           5      Airport      264.0     Trip Completed
# 4100           6         City        NaN  No Cars Available
# 4099           7      Airport        NaN  No Cars Available
# 4102           8         City        NaN  No Cars Available
# 2245           9      Airport      235.0     Trip Completed
# 2173          10         City      228.0     Trip Completed
# 1884          11         City      198.0     Trip Completed
# 4103          12         City        NaN  No Cars Available
# 1144          13         City      119.0     Trip Completed
# 4105          14      Airport        NaN  No Cars Available
# 4107          15         City        NaN  No Cars Available
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
if loc{uber_data['Status']==''

# %%
Status=uber_data['Status']

# %%
RDate=uber_data["Reqeust Date"]

# %%
sns.catplot(x="Status",kind="count", palette="ch:.25",  data=uber_data);

# %%
sns.catplot(x="Status",kind="count", hue='Pickup point', palette="ch:.25",  data=uber_data);

# %%
sns.catplot(x="Segment", kind="count", palette="ch:.25", data=uber_data);

# %%
sns.catplot(x="Segment", kind="count", hue='Pickup point', palette="ch:.25", data=uber_data);

# %%
sns.catplot(x="Pickup point", kind="count", palette="ch:.25", data=uber_data);

# %%
sns.catplot(x="Pickup point", kind="count", hue='Supply', palette="ch:.25", data=uber_data);

# %%
uber_data['Supply']=0

# %%
uber_data['Supply'].loc[uber_data['Status']=='Trip Completed']=1
# Out:
# C:\Users\vinay\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
uber_data.head(100)
# Out:
#       Request id Pickup point  Driver id             Status  \
# 2700           1      Airport      285.0     Trip Completed
# 4098           2      Airport        NaN  No Cars Available
# 776            3      Airport       80.0     Trip Completed
# 4101           4         City        NaN  No Cars Available
# 2506           5      Airport      264.0     Trip Completed
# 4100           6         City        NaN  No Cars Available
# 4099           7      Airport        NaN  No Cars Available
# 4102           8         City        NaN  No Cars Available
# 2245           9      Airport      235.0     Trip Completed
# 2173          10         City      228.0     Trip Completed
# 1884          11         City      198.0     Trip Completed
# 4103          12         City        NaN  No Cars Available
# 1144          13         City      119.0     Trip Completed
# 4105          14      Airport        NaN  No Cars Available
# 4107          15         City        NaN  No Cars Available
# ...

# %%
sns.catplot(x="hr", y='Supply',kind="point", palette="ch:.25", data=uber_data);
# Out:
# C:\Users\vinay\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.catplot(x="Segment", y='Supply',kind="point", palette="ch:.25",  data=uber_data);
# Out:
# C:\Users\vinay\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.catplot(x="Pickup point", y='Supply', kind="point", palette="ch:.25", data=uber_data);
# Out:
# C:\Users\vinay\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
